# %% [markdown]
# <a href="https://colab.research.google.com/github/codeXsuman/Data-Science-workshop/blob/main/DAY1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  best for data science [kaggle](https://kaggle.com)

# %%
print("Oh captain my captain")
# Out:
# Oh captain my captain

# %%
print('''  '"Oh captain my "captain"'  ''')
# Out:
#   '"Oh captain my "captain"'

# %%
print("My name is Suman\n\t My age is 20")
# Out:
# My name is Suman
# 	 My age is 20

# %%
name = "Suman"
age = "20"
marks = "99"

print(name)
print(age)
print(marks)
# Out:
# Suman
# 20
# 99

# %%
name = "Suman"
age = "20"
marks = "99"

print("my name is ", name)
print("my age is ",age)
print("my marks is ", marks)
# Out:
# my name is  Suman
# my age is  20
# my marks is  99

# %%
name = "suman"
age = "20"
marks = 99
a = (marks)
marks_in_other_sub = 343
b = (marks_in_other_sub)
sum = a+b
Total_marks = sum

print("I got",marks,"marks")
print("my total marks are:",Total_marks)
# Out:
# I got 99 marks
# my total marks are: 442

# %%
name = "suman"
age = 20
marks = 98.10
topper = True

print(type(name))
print(type(age))
print(type(marks))
print(type(topper))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
a = 2
b = 3

# Arithmatic Operators
print("sum (a+b)=",a+b)
print("multipication(a x b):",a*b)
print("division(a/b):", a/b)
print("remainder(a%b):", a%b)
print("a to the power b(a^b):",a**b)

print("")

print(a==b)
print(a!=b)
print("Greater than :", a>b)
print("less than :",a<b)
print(a>=b)
print(a<=b)
# Out:
# sum (a+b)= 5
# multipication(a x b): 6
# division(a/b): 0.6666666666666666
# remainder(a%b): 2
# a to the power b(a^b): 8
#
# False
# True
# Greater than : False
# less than : True
# False
# True

# %%
x = 10
print("Initial value of x:", x)

x = 5
print("After assigning x =", x)

x += 3
print("After adding(x = x+3):", x)

x -= 2
print("after substrating(x = x-2):", x)

x *= 3
print("after multipication:", x)

x /= 2
print("after division", x)
# Out:
# Initial value of x: 10
# After assigning x = 5
# After adding(x = x+3): 8
# after substrating(x = x-2): 6
# after multipication: 18
# after division 9.0

# %%
#logical opetator
a = True
b = False
#AND
print("a and b:", a and b)
#OR
print("a or b:", a or b)
#NOT
print("not a:",not a)
print("not b:",not b)
# Out:
# a and b: False
# a or b: True
# not a: False
# not b: True

# %%
#STRING

str1 = "This is a string"
str2 = "Data science with python"
str3 = "by CSI"

length1 = len(str1)
length2 = len(str2)
length3 = len(str3)

print(str1 + " " + str2 + " " + str3)

print(length1)
print(length2)
print(length3)
# Out:
# This is a string Data science with python by CSI
# 16
# 24
# 6

# %%
str = "python"
print(str[4])
# Out:
# o

# %%
str = "python"
print(str[-1]) # count starting from -1
print(str[-2])
print(str[-6])
# Out:
# n
# o
# p

# %%
#SLICEING
text = "Data Science"
print(text[0:4])
print(text[6:8])
print(text[:4])
print(text[-6:-1])
print(text[::3]) # jumping every time in gap of 3
print(text[::-1])
# Out:
# Data
# ci
# Data
# cienc
# Dacn
# ecneicS ataD

# %%
text = "data Science with Python"
#1
print("Length:", len(text))
#2
print("uppercase:", text.upper())
#3
print("lowercase:",text.lower())
#4
print("capitalise:", text.capitalize())
#5
print("Replace:", text.replace("Python", "AI"))
#6
print("Find 'science':",  text.find("Science"))
#7
print("Count of 'a':", text.count("a"))
#8
print("Start with 'Data':", text.startswith("python"))
#9
print("Ends with 'python':", text.endswith("Python"))
#10
print("split words: ", text.split())
# Out:
# Length: 24
# uppercase: DATA SCIENCE WITH PYTHON
# lowercase: data science with python
# capitalise: Data science with python
# Replace: data Science with AI
# Find 'science': 5
# Count of 'a': 2
# Start with 'Data': False
# Ends with 'python': True
# split words:  ['data', 'Science', 'with', 'Python']

# %%
#CONDITIONAL STATEMENTS
age = 18
if age >= 18:
  print("you are eligible to vote")
# Out:
# you are eligible to vote

# %%
number = 10

if number%2 == 0:
  print("Even Number")
else:
  print("Odd number")
# Out:
# Even Number

# %%
marks = 75

if marks >= 90:
  print("Grade A")
elif marks >= 70:
  print("Grade B")
elif marks >= 50:
  print("Grade C")
else:
  print("Fail!")
# Out:
# Grade B

# %%
num = -5
if num > 0:
  print("Positive Number")
elif num == 0:
  print("Zero")
else:
  print("Negative Number")
# Out:
# Negative Number

# %%
age = int(input("Enter your age: "))

if age >= 18:
  print("You can vote")
else:
  print("You can not vote")
# Out:
# Enter your age: 22
# You can vote

# %%
age = 20
citizen = "yes"

if age >= 18:
  if citizen == "yes":
    print("eligible to vote")
  else:
    print("Not a citizen")
else:
  print("Underage")
# Out:
# eligible to vote

# %%
def greet():
  print("Hello, welcome to python")

greet()
# Out:
# Hello, welcome to python
